# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

cancerRegistries = ["Bangalore", "Barshi Rural", "Barshi Expanded", "Bhopal", "Chennai", 
                    "Delhi", "Mumbai", "Cachar District", "Dibrugarh District", 
                    "Kamrup Urban District", "Manipur State MR", "Imphal West District", 
                    "MR Excl Imphal West", "Mizoram State MZ", "Aizawl District", 
                    "MZ Excl Aizawl", "Sikkim State", "Ahmedabad Urban", "Aurangabad", 
                    "Kolkata", "Kollam District", "Nagpur", "Pune", "Thiruvananthapuram District", 
                    "Meghalaya", "East Khasi Hills District", "Tripura State", 
                    "Nagaland", "Wardha District", "Naharlagun NH", "Papumpare District",
                    "NH Excl Papumpare", "Pasighat", "Patiala District"]

print "Cancer registries (total) considered are : ", len(cancerRegistries)

maleCases = (3824, 454, 901, 1718, 5447, 10148, 6598, 2666, 1498, 3071, 2081, 640,
1441, 2567, 1275, 1292, 707, 5477, 1123, 2777, 5534, 2236, 3417, 7638, 2632, 1624,
3628, 815, 1306, 735, 299, 436, 175, 2853)

print "Male cases are : ", len(maleCases)

femaleCases = (4547, 475, 1131, 746, 6212, 9598, 6759, 2100, 1345, 2392, 2542, 823,
1719, 2089, 1066, 1023, 678, 4117, 1118, 2596, 5478, 2417, 3686, 8002, 1616, 988, 
2702, 546, 1424, 704, 333, 371, 159, 3158)

print "Female cases are : ", len(femaleCases)

index = np.arange(len(cancerRegistries))
width = 0.50

fig, ax = plt.subplots()
barSet1 = ax.bar(index, maleCases, width, color='b')
barSet2 = ax.bar(index+width, femaleCases, width, color='m')

ax.set_ylabel('Cancer Incidence')
ax.set_title('Total Number of Cases Registered for all PBCRs')
ax.set_xticks(index+width)
ax.set_xticklabels(cancerRegistries, rotation=45)
""" ax.set_xticklabels(("Bangalore", "Barshi Rural", "Barshi Expanded", "Bhopal", "Chennai", 
                    "Delhi", "Mumbai", "Cachar District", "Dibrugarh District", 
                    "Kamrup Urban District", "Manipur State MR", "Imphal West District", 
                    "MR Excl Imphal West", "Mizoram State MZ", "Aizawl District", 
                    "MZ Excl Aizawl", "Sikkim State", "Ahmedabad Urban", "Aurangabad", 
                    "Kolkata", "Kollam District", "Nagpur", "Pune", "Thiruvananthapuram District", 
                    "Meghalaya", "East Khasi Hills District", "Tripura State", 
                    "Nagaland", "Wardha District", "Naharlagun NH", "Papumpare District",
                    "NH Excl Papumpare", "Pasighat", "Patiala District")) """

ax.legend((barSet1[0], barSet2[0]), ("Male", "Female"))

plt.show()
# Out:
# Cancer registries (total) considered are :  34
# Male cases are :  34
# Female cases are :  34
